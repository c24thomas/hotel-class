# %% [markdown]
# ### Creating a Convolutional Neural Network
#
# In this notebook, we go through the process of building a convolutional neural network.
#
# This notebook does not contain all the iterations that came before.
#
# We started by first building a CNN that was massively overfit. Then we applied regularization in an attempt to control the loss. That worked great, but it also made the accuracy plummet to below 2%, including for the training set.
#
# This notebook summarizes the process of fine tuning the CNN so that it can have some accuracy without having crazy loss.
#
# Some cells and outputs are missing because of failing to transfer all the work done on Google Colab before getting the session shut down. However, it does focus on one model that performed better than most and how it was trained.
#
# The next notebook focuses on gathering predictions from a trained model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import PIL
import PIL.Image
import shutil
import pathlib
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
else:
  print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
tf.random.set_seed(42)

# %%
# !mkdir kaggle_dataset

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content/kaggle_dataset'

# %%
# !pip uninstall -y kaggle
# !pip install --upgrade pip
# !pip install kaggle==1.5.6

# %%
# !chmod 600 /content/kaggle_dataset/kaggle.json

# %%
# !kaggle competitions download -c hotel-id-2021-fgvc8 --force
# Out:
# Downloading hotel-id-2021-fgvc8.zip to /content
# 100% 24.4G/24.4G [05:10<00:00, 170MB/s]
# 100% 24.4G/24.4G [05:10<00:00, 84.4MB/s]

# %%
# !unzip hotel-id-2021-fgvc8.zip -d /content/kaggle_dataset/hotels/

# %%
train_df = pd.read_csv('/content/kaggle_dataset/hotels/train.csv')

# %%
train_df = train_df.drop_duplicates(subset=['image'], keep='first')

# %%
folders = [str(chain) for chain in range(0, 92)]
dir = "/content/kaggle_dataset/hotels/train_images/"
hotels_dir = f"/content/kaggle_dataset/hotels/train_images_by_id/"
for folder in folders:
  chain_path = dir + folder + '/'
  if os.path.exists(chain_path):
    for file in os.listdir(chain_path):
      if file.endswith('.jpg'):
        hotel_id = str(train_df[train_df['image'] == file]['hotel_id'].values[0])
        hotel_dir = hotels_dir + hotel_id
        if not os.path.exists(hotel_dir):
          os.makedirs(hotel_dir)
        if os.path.exists(hotel_dir):
          file_path = chain_path + file
          shutil.move(file_path, hotel_dir)

# %%
# !mkdir /content/kaggle_dataset/hotels/batches

# %%
# moves from batches back to hotel ids
# handy for when you screw stuff up

# dir = '/content/kaggle_dataset/hotels/batches/'
# train_dir = '/content/kaggle_dataset/hotels/train_images_by_id/'
# for i in range(1, 15):
#   for root, dirs, files in os.walk(f'{dir}batch_{i}', topdown=False):
#     hotel_id = root.split('/')[-1]
#     destination = f'{train_dir}{hotel_id}'
#     for file in files:
#       file_path = root + '/' + file
#       shutil.move(file_path, destination)

# %%
# moves from hotel id folders to batches
dir = "/content/kaggle_dataset/hotels/train_images_by_id/"
batches_dir = "/content/kaggle_dataset/hotels/batches/"
id_count = 0
batch = 1
for root, dirs, files in os.walk(dir, topdown=False):
  id_count += 1
  batch_dir = f'batch_{batch}/'
  batch_directory = batches_dir + batch_dir
  if not os.path.exists(batch_directory):
    os.makedirs(batch_directory)
  if id_count <= 500:
  
    hotel_id = root.split('/')[-1]
    batch_hotel_dir = f'{batch_directory}{hotel_id}/' 
    if not os.path.exists(batch_hotel_dir):
      os.makedirs(batch_hotel_dir)
    if os.path.exists(batch_hotel_dir):
      for file in files:
        shutil.move(root + '/' + file, batch_hotel_dir)
  else:
    batch += 1
    id_count = 0

# %%
batches_dir = "/content/kaggle_dataset/hotels/batches/batch_"
for i in range(1, 10):
  batch_dir = f'{batches_dir}{i}'
  print(len(os.listdir(batch_dir)))

# %%
def get_batchsets(batch_num):
  batch_size = 32
  img_height = 56
  img_width = 56
  hotels_dir = f"/content/kaggle_dataset/hotels/batches/batch_{batch_num}/"
  train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    hotels_dir,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    seed=123,
    subset='training',
    validation_split=0.2,
    label_mode='int'
  )
  val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  hotels_dir,
  validation_split=0.2,
  subset='validation',
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  label_mode='int'
)
  return (train_ds, val_ds)

# %%
train_ds_b, val_ds_b = get_batchsets(1)
train_ds_b
# Out:
# Found 6115 files belonging to 500 classes.
# Using 4892 files for training.
# Found 6115 files belonging to 500 classes.
# Using 1223 files for validation.
# <BatchDataset shapes: ((None, 56, 56, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
class_names = train_ds_b.class_names

# %%
def cache_ds(train_ds, val_ds):
  AUTOTUNE = tf.data.AUTOTUNE
  train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
  return(train_ds, val_ds)

# %%
train_ds_b, val_ds_b = cache_ds(train_ds_b, val_ds_b)

# %%
def show_images(image_ds, take=1):
  plt.figure(figsize=(10,10))
  for images, labels in image_ds.take(take):
    for i in range(9):
      ax = plt.subplot(3, 3, i+1)
      plt.imshow(images[i].numpy().astype("uint8"))
      plt.title(class_names[labels[i]])
      plt.axis('off')

# %% [markdown]
# View some images in our training set:

# %%
show_images(train_ds_b)

# %%
num_classes = len(class_names)
num_classes
# Out:
# 500

# %% [markdown]
# ### class ConvNet
#
# This class can be used to instantiate models more quickly.
#
# It also keeps track of the "best" model seen so far and the "best" accuracy.

# %%
class ConvNet:
  models = []
  best_model = None
  best_acc = 0
  """
  arguments:
  cFilters: list of tuples describing each conv2d layer (int filters, float l2 regularization)
  dLayers: list of tuples describing each dense layer (int nodes, float l2 regularization, float dropout)
  """
  def __init__(self, cFilters=[(64,0)], dLayers=[(800,0,0)]):
    self.hyperparameters = {
        'cFilters': cFilters,
        'dLayers': dLayers
    }
    self.create_model(cFilters, dLayers)
    
  def create_model(self, cFilters, dLayers):
    model = tf.keras.Sequential()
    model.add(layers.experimental.preprocessing.Rescaling(1./255))
    model.add(layers.experimental.preprocessing.RandomFlip('horizontal'))
    model.add(layers.experimental.preprocessing.RandomZoom(0.2))
    model.add(layers.experimental.preprocessing.RandomRotation(0.1))
    model.add(layers.experimental.preprocessing.CenterCrop(28, 28))
    for cFilter, reg in cFilters:
      model.add(layers.Conv2D(cFilter, 3, padding='same', activation='relu', kernel_regularizer=l2(reg)))
      model.add(layers.MaxPooling2D(padding='valid'))
    model.add(layers.Flatten())
    for dLayer, reg, drop in dLayers:
      model.add(layers.Dense(dLayer, activation='relu', kernel_regularizer=l2(reg)))
      model.add(layers.Dropout(drop))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(
      optimizer='adam',
      loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
      metrics=['accuracy'])
    self.model = model
  def fit(self, train_ds, val_ds, epochs=100, batch_size=16):
    history = self.model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
    best_acc = max(history.history['val_accuracy'])
    print('best acc', best_acc)
    if best_acc > ConvNet.best_acc:
      ConvNet.best_acc = best_acc
      ConvNet.best_model = self
    ConvNet.models.append(self.model)
    self.history = history
    return history

# %% [markdown]
# I'm not including all the outputs from these next cells because they're here to just show the process by which I used a shotgun approach to find a model that looked promising. It's sort of like my homemade GridSearch. In this notebook I focus on one model that performed better than most.

# %%
convNets = []
cLayers =[[(100, 0), (32, 0)], [(100, 1e-5), (32, 0)], [(64, 0), (32, 0)], [(100, 1e-5), (16, 0), (16, 0)]]
dLayers = [[(400, 0, 0.6), (200, 0, 0.6)], [(400, 1e-5, 0.6), (200, 0, 0.6)]]
for c in cLayers:
  for d in dLayers:
    convNets.append(ConvNet(c, d))

# %%
for i, cn in enumerate(convNets):
  print('progress:', i, 'best:', ConvNet.best_acc )
  cn.fit(train_ds, val_ds, 1000)

# %%
ConvNet.best_acc
# Out:
# 0.0735759511590004

# %%
history1 = convNets[0].fit(train_ds_b, val_ds_b)
# Out:
# Epoch 1/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2857 - accuracy: 0.0959 - val_loss: 6.9761 - val_accuracy: 0.0736
# Epoch 2/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2526 - accuracy: 0.1030 - val_loss: 6.9408 - val_accuracy: 0.0720
# Epoch 3/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2458 - accuracy: 0.1024 - val_loss: 7.0085 - val_accuracy: 0.0760
# Epoch 4/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2832 - accuracy: 0.1092 - val_loss: 6.9682 - val_accuracy: 0.0703
# Epoch 5/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2730 - accuracy: 0.1026 - val_loss: 6.9262 - val_accuracy: 0.0760
# Epoch 6/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2425 - accuracy: 0.1049 - val_loss: 7.0435 - val_accuracy: 0.0744
# Epoch 7/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2886 - accuracy: 0.1120 - val_loss: 6.8945 - val_accuracy: 0.0769
# Epoch 8/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2590 - accuracy: 0.1032 - val_loss: 6.9833 - val_accuracy: 0.0687
# Epoch 9/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2334 - accuracy: 0.1096 - val_loss: 7.0120 - val_accuracy: 0.0785
# Epoch 10/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2384 - accuracy: 0.1045 - val_loss: 6.9556 - val_accuracy: 0.0720
# Epoch 11/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2519 - accuracy: 0.1045 - val_loss: 7.0494 - val_accuracy: 0.0752
# Epoch 12/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2083 - accuracy: 0.1063 - val_loss: 7.0888 - val_accuracy: 0.0720
# Epoch 13/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2161 - accuracy: 0.1006 - val_loss: 7.1698 - val_accuracy: 0.0720
# Epoch 14/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2237 - accuracy: 0.1098 - val_loss: 7.0398 - val_accuracy: 0.0744
# Epoch 15/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2006 - accuracy: 0.1075 - val_loss: 7.0448 - val_accuracy: 0.0728
# Epoch 16/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2075 - accuracy: 0.1077 - val_loss: 6.9871 - val_accuracy: 0.0662
# Epoch 17/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2448 - accuracy: 0.1032 - val_loss: 7.1113 - val_accuracy: 0.0687
# Epoch 18/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1985 - accuracy: 0.1077 - val_loss: 7.1953 - val_accuracy: 0.0687
# Epoch 19/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2433 - accuracy: 0.1053 - val_loss: 7.1845 - val_accuracy: 0.0801
# Epoch 20/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1926 - accuracy: 0.1128 - val_loss: 7.1014 - val_accuracy: 0.0711
# Epoch 21/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2053 - accuracy: 0.1077 - val_loss: 7.2999 - val_accuracy: 0.0711
# Epoch 22/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2327 - accuracy: 0.1106 - val_loss: 7.1488 - val_accuracy: 0.0711
# Epoch 23/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2153 - accuracy: 0.1108 - val_loss: 7.1214 - val_accuracy: 0.0785
# Epoch 24/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2497 - accuracy: 0.1006 - val_loss: 7.0941 - val_accuracy: 0.0695
# Epoch 25/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2202 - accuracy: 0.1018 - val_loss: 7.0790 - val_accuracy: 0.0760
# Epoch 26/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1995 - accuracy: 0.1096 - val_loss: 7.3373 - val_accuracy: 0.0720
# Epoch 27/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2112 - accuracy: 0.1038 - val_loss: 7.2063 - val_accuracy: 0.0752
# Epoch 28/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1734 - accuracy: 0.1157 - val_loss: 7.2608 - val_accuracy: 0.0752
# Epoch 29/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1767 - accuracy: 0.1083 - val_loss: 7.1729 - val_accuracy: 0.0744
# Epoch 30/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2316 - accuracy: 0.1059 - val_loss: 7.0976 - val_accuracy: 0.0777
# Epoch 31/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1956 - accuracy: 0.1069 - val_loss: 7.3104 - val_accuracy: 0.0736
# Epoch 32/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1580 - accuracy: 0.1155 - val_loss: 7.4062 - val_accuracy: 0.0670
# Epoch 33/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1976 - accuracy: 0.1085 - val_loss: 7.1099 - val_accuracy: 0.0736
# Epoch 34/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2169 - accuracy: 0.1012 - val_loss: 7.1698 - val_accuracy: 0.0687
# Epoch 35/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1500 - accuracy: 0.1083 - val_loss: 7.4159 - val_accuracy: 0.0711
# Epoch 36/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2141 - accuracy: 0.1065 - val_loss: 7.2772 - val_accuracy: 0.0728
# Epoch 37/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1946 - accuracy: 0.1110 - val_loss: 7.1253 - val_accuracy: 0.0752
# Epoch 38/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1952 - accuracy: 0.1128 - val_loss: 7.2928 - val_accuracy: 0.0720
# Epoch 39/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2062 - accuracy: 0.1073 - val_loss: 7.1773 - val_accuracy: 0.0670
# Epoch 40/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1706 - accuracy: 0.1087 - val_loss: 7.1807 - val_accuracy: 0.0720
# Epoch 41/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1551 - accuracy: 0.1188 - val_loss: 7.2278 - val_accuracy: 0.0720
# Epoch 42/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1662 - accuracy: 0.1098 - val_loss: 7.2448 - val_accuracy: 0.0744
# Epoch 43/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1693 - accuracy: 0.1126 - val_loss: 7.1386 - val_accuracy: 0.0728
# Epoch 44/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1723 - accuracy: 0.1141 - val_loss: 7.3309 - val_accuracy: 0.0744
# Epoch 45/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1724 - accuracy: 0.1149 - val_loss: 7.3903 - val_accuracy: 0.0752
# Epoch 46/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1608 - accuracy: 0.1139 - val_loss: 7.1877 - val_accuracy: 0.0777
# Epoch 47/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1420 - accuracy: 0.1179 - val_loss: 7.1356 - val_accuracy: 0.0720
# Epoch 48/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1986 - accuracy: 0.1077 - val_loss: 7.1731 - val_accuracy: 0.0711
# Epoch 49/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1427 - accuracy: 0.1143 - val_loss: 7.3200 - val_accuracy: 0.0670
# Epoch 50/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1799 - accuracy: 0.1106 - val_loss: 7.2967 - val_accuracy: 0.0695
# Epoch 51/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1429 - accuracy: 0.1106 - val_loss: 7.3626 - val_accuracy: 0.0777
# Epoch 52/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1266 - accuracy: 0.1077 - val_loss: 7.3945 - val_accuracy: 0.0744
# Epoch 53/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1612 - accuracy: 0.1122 - val_loss: 7.2990 - val_accuracy: 0.0769
# Epoch 54/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1741 - accuracy: 0.1175 - val_loss: 7.1228 - val_accuracy: 0.0736
# Epoch 55/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1307 - accuracy: 0.1163 - val_loss: 7.4257 - val_accuracy: 0.0703
# Epoch 56/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1726 - accuracy: 0.1075 - val_loss: 7.2016 - val_accuracy: 0.0777
# Epoch 57/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.2125 - accuracy: 0.1130 - val_loss: 7.2328 - val_accuracy: 0.0760
# Epoch 58/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1679 - accuracy: 0.1141 - val_loss: 7.1839 - val_accuracy: 0.0777
# Epoch 59/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1388 - accuracy: 0.1190 - val_loss: 7.3411 - val_accuracy: 0.0736
# Epoch 60/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1537 - accuracy: 0.1081 - val_loss: 7.4017 - val_accuracy: 0.0777
# Epoch 61/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1308 - accuracy: 0.1200 - val_loss: 7.1995 - val_accuracy: 0.0769
# Epoch 62/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1441 - accuracy: 0.1153 - val_loss: 7.3678 - val_accuracy: 0.0736
# Epoch 63/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1580 - accuracy: 0.1167 - val_loss: 7.4302 - val_accuracy: 0.0711
# Epoch 64/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1418 - accuracy: 0.1122 - val_loss: 7.4234 - val_accuracy: 0.0744
# Epoch 65/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1484 - accuracy: 0.1216 - val_loss: 7.3779 - val_accuracy: 0.0760
# Epoch 66/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1344 - accuracy: 0.1165 - val_loss: 7.5113 - val_accuracy: 0.0752
# Epoch 67/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1276 - accuracy: 0.1173 - val_loss: 7.4477 - val_accuracy: 0.0662
# Epoch 68/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1389 - accuracy: 0.1112 - val_loss: 7.3657 - val_accuracy: 0.0711
# Epoch 69/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1108 - accuracy: 0.1204 - val_loss: 7.3557 - val_accuracy: 0.0785
# Epoch 70/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1340 - accuracy: 0.1137 - val_loss: 7.3180 - val_accuracy: 0.0728
# Epoch 71/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0861 - accuracy: 0.1175 - val_loss: 7.3796 - val_accuracy: 0.0744
# Epoch 72/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0977 - accuracy: 0.1128 - val_loss: 7.5491 - val_accuracy: 0.0638
# Epoch 73/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1213 - accuracy: 0.1063 - val_loss: 7.4189 - val_accuracy: 0.0703
# Epoch 74/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0898 - accuracy: 0.1198 - val_loss: 7.5934 - val_accuracy: 0.0752
# Epoch 75/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1290 - accuracy: 0.1112 - val_loss: 7.4480 - val_accuracy: 0.0736
# Epoch 76/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1454 - accuracy: 0.1145 - val_loss: 7.5630 - val_accuracy: 0.0711
# Epoch 77/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0897 - accuracy: 0.1212 - val_loss: 7.5765 - val_accuracy: 0.0662
# Epoch 78/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0928 - accuracy: 0.1194 - val_loss: 7.4406 - val_accuracy: 0.0630
# Epoch 79/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1161 - accuracy: 0.1206 - val_loss: 7.3713 - val_accuracy: 0.0662
# Epoch 80/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0981 - accuracy: 0.1169 - val_loss: 7.3178 - val_accuracy: 0.0662
# Epoch 81/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0963 - accuracy: 0.1198 - val_loss: 7.3564 - val_accuracy: 0.0695
# Epoch 82/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0931 - accuracy: 0.1239 - val_loss: 7.3529 - val_accuracy: 0.0760
# Epoch 83/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0441 - accuracy: 0.1233 - val_loss: 7.5281 - val_accuracy: 0.0720
# Epoch 84/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0712 - accuracy: 0.1241 - val_loss: 7.3799 - val_accuracy: 0.0777
# Epoch 85/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1366 - accuracy: 0.1110 - val_loss: 7.4168 - val_accuracy: 0.0744
# Epoch 86/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0791 - accuracy: 0.1132 - val_loss: 7.5168 - val_accuracy: 0.0769
# Epoch 87/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0804 - accuracy: 0.1208 - val_loss: 7.3386 - val_accuracy: 0.0793
# Epoch 88/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0942 - accuracy: 0.1147 - val_loss: 7.4161 - val_accuracy: 0.0752
# Epoch 89/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0919 - accuracy: 0.1200 - val_loss: 7.4401 - val_accuracy: 0.0703
# Epoch 90/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1014 - accuracy: 0.1188 - val_loss: 7.4401 - val_accuracy: 0.0720
# Epoch 91/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1045 - accuracy: 0.1128 - val_loss: 7.5852 - val_accuracy: 0.0752
# Epoch 92/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1179 - accuracy: 0.1204 - val_loss: 7.4740 - val_accuracy: 0.0760
# Epoch 93/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0691 - accuracy: 0.1218 - val_loss: 7.4154 - val_accuracy: 0.0736
# Epoch 94/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1178 - accuracy: 0.1147 - val_loss: 7.3752 - val_accuracy: 0.0809
# Epoch 95/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.1171 - accuracy: 0.1161 - val_loss: 7.3735 - val_accuracy: 0.0769
# Epoch 96/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0435 - accuracy: 0.1208 - val_loss: 7.5211 - val_accuracy: 0.0777
# Epoch 97/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0794 - accuracy: 0.1224 - val_loss: 7.4013 - val_accuracy: 0.0736
# Epoch 98/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0693 - accuracy: 0.1216 - val_loss: 7.4619 - val_accuracy: 0.0728
# Epoch 99/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0597 - accuracy: 0.1278 - val_loss: 7.4651 - val_accuracy: 0.0752
# Epoch 100/100
# 153/153 [==============================] - 1s 7ms/step - loss: 4.0973 - accuracy: 0.1216 - val_loss: 7.4586 - val_accuracy: 0.0670
# best acc 0.08094848692417145

# %%
def plot_history(history, epochs):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(8, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')

# %% [markdown]
# ### Plotting a journey of training
#
# These plots serve as a time series of training a model that was pretty typical during our numerous numerous numerous iterations

# %%
plot_history(history1, 100)

# %% [markdown]
# This model looks promising for a while during the first 100 epochs of training, but loss starts to creep up and accuracy starts to flatten out around 6%.

# %%
plot_history(history1, 100)

# %% [markdown]
# During the next 100 epochs of training, it looks like we've gotten all we can out of this model. The training set is continuing to learn, but the validation set has flattened out in accuracy. Meanwhile, loss for the training set is falling, but for the validation set it's climbing.

# %%
plot_history(history1, 100)

# %% [markdown]
# Just to be sure, we trained the model for another 100 epochs. It seems like this is the best it's going to get.
#
# #### Final metrics:
#
#     Training loss:  4.0973
#     Training accuracy: 0.1216
#     Validation loss: 7.4586
#     Validation accuracy: 0.0670
#
# We'll cover testing predictions and getting the top five predictions in the next notebook.
